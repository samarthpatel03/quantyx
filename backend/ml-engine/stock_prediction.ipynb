# %% [markdown]
# # Stock Movement Prediction — Reliance Industries
# ## Quantitative Market Analysis Project
#
# Predicting whether Reliance Industries (RELIANCE.NS) stock will go
# **UP or DOWN** the next trading day using technical indicators and machine learning.
#
# ### Why Direction Prediction?
# Rather than predicting exact stock prices — which is misleading and practically
# useless — this project frames the problem as **binary classification**.
# Predicting direction is how real quantitative hedge funds approach alpha research.
#
# ### Project Structure
# 1. Data Collection
# 2. Target Variable Creation
# 3. Feature Engineering
# 4. Exploratory Data Analysis
# 5. Modelling & Evaluation
# 6. Strategy Returns
# 7. Live Prediction

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from xgboost import XGBClassifier
import joblib
import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Data Collection
# Downloading 3 years of daily OHLCV data for Reliance Industries using `yfinance`.
#
# **OHLCV:** Open, High, Low, Close, Volume — the standard format for daily stock data.
#
# The data period 2022-2025 was chosen to capture multiple market cycles including
# bull runs, corrections, and sideways periods.

# %%
# df = yf.download("HDFCBANK.NS",start="2015-03-01",end="2026-03-01")
df = yf.download("RELIANCE.NS",start="2022-03-01", end="2026-03-01")

df.columns = df.columns.droplevel(1)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price             Close         High          Low         Open    Volume
# Date
# 2022-03-02  1091.369263  1092.484104  1059.814182  1062.202973  21471786
# 2022-03-03  1082.155029  1098.785697  1078.401181  1092.028770  10186748
# 2022-03-04  1058.153198  1075.784852  1055.787154  1070.643199  10805667
# 2022-03-07  1019.022217  1052.033337  1011.036713  1036.835847  17983310
# 2022-03-08  1017.179382  1021.957085   991.926235  1006.259101  21289374

# %%
df.tail()
# Out:
# Price             Close         High          Low         Open    Volume
# Date
# 2026-02-23  1428.000000  1434.900024  1418.300049  1425.000000   7758856
# 2026-02-24  1428.800049  1433.300049  1415.000000  1425.300049  12529409
# 2026-02-25  1398.500000  1440.500000  1393.500000  1435.000000  10728792
# 2026-02-26  1406.800049  1412.900024  1391.900024  1398.500000  16683858
# 2026-02-27  1393.900024  1410.400024  1388.099976  1398.000000  12031440

# %% [markdown]
# ## 2. Target Variable
# Creating a binary classification target:
# - **1 (UP)** — tomorrow's closing price is higher than today's
# - **0 (DOWN)** — tomorrow's closing price is lower than today's
#
# We use **Close-to-Close returns** rather than Close-to-Open because:
# - Open prices are affected by overnight gaps and pre-market news
# - Close-to-Close gives a clean, consistent daily return
# - This is standard practice in quantitative finance

# %%
return_=(df['Close'].shift(-1)-df['Close'])/df['Close']
df['Target']=(return_>0).astype(int)

# %%
print(df['Target'].value_counts())
print(df['Target'].head(10))
print(return_.head(10))
# Out:
# Target
# 1    505
# 0    484
# Name: count, dtype: int64
# Date
# 2022-03-02    0
# 2022-03-03    0
# 2022-03-04    0
# 2022-03-07    0
# 2022-03-08    1
# 2022-03-09    1
# 2022-03-10    1
# 2022-03-11    1
# 2022-03-14    0
# 2022-03-15    1
# Name: Target, dtype: int64
# Date
# 2022-03-02   -0.008443
# 2022-03-03   -0.022180
# 2022-03-04   -0.036980
# 2022-03-07   -0.001808
# 2022-03-08    0.053053
# 2022-03-09    0.016206
# 2022-03-10    0.002884
# 2022-03-11    0.008211
# 2022-03-14   -0.022903
# 2022-03-15    0.016882
# Name: Close, dtype: float64

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (989, 6)

# %% [markdown]
# ## 3. Feature Engineering
# Building 9 technical indicators from raw OHLCV data.
#
# **Key principle — Data Leakage Prevention:**
# All features are calculated using only past data available at the end of each
# trading day. No future information is used. This is critical for time series
# models — using future data to predict the future is the most common and fatal
# mistake in financial ML.

# %% [markdown]
# ### Simple Moving Averages (SMA 20 & SMA 50)
# Average closing price over 20 and 50 days respectively.
# - **Golden Cross** — SMA 20 crosses above SMA 50 → bullish signal
# - **Death Cross** — SMA 20 crosses below SMA 50 → bearish signal
#
# First N rows will be NaN — expected behavior as rolling windows need
# minimum data points to compute.

# %%
df['SMA_20'] = df['Close'].rolling(window=20).mean()
df['SMA_50'] = df['Close'].rolling(window=50).mean()

# %%
df[['Close','SMA_20','SMA_50']].head(60)
# Out:
# Price             Close       SMA_20       SMA_50
# Date
# 2022-03-02  1091.369263          NaN          NaN
# 2022-03-03  1082.155029          NaN          NaN
# 2022-03-04  1058.153198          NaN          NaN
# 2022-03-07  1019.022217          NaN          NaN
# 2022-03-08  1017.179382          NaN          NaN
# 2022-03-09  1071.143799          NaN          NaN
# 2022-03-10  1088.502441          NaN          NaN
# 2022-03-11  1091.642090          NaN          NaN
# 2022-03-14  1100.605713          NaN          NaN
# 2022-03-15  1075.398071          NaN          NaN
# 2022-03-16  1093.553101          NaN          NaN
# 2022-03-17  1129.203491          NaN          NaN
# 2022-03-21  1122.696655          NaN          NaN
# 2022-03-22  1151.703857          NaN          NaN
# 2022-03-23  1155.366455          NaN          NaN
# 2022-03-24  1173.316650          NaN          NaN
# 2022-03-25  1181.142944          NaN          NaN
# 2022-03-28  1193.018921          NaN          NaN
# 2022-03-29  1193.291870          NaN          NaN
# 2022-03-30  1216.224487  1115.234482          NaN
# 2022-03-31  1198.842896  1120.608163          NaN
# 2022-04-01  1208.443604  1126.922592          NaN
# 2022-04-04  1212.015503  1134.615707          NaN
# 2022-04-05  1194.884277  1143.408810          NaN
# 2022-04-06  1191.699219  1152.134802          NaN
# 2022-04-07  1170.677856  1157.111505          NaN
# 2022-04-08  1190.152222  1162.193994          NaN
# 2022-04-11  1187.672485  1166.995514          NaN
# 2022-04-12  1165.308594  1170.230658          NaN
# 2022-04-13  1161.031372  1174.512323          NaN
# 2022-04-18  1157.482300  1177.708783          NaN
# 2022-04-19  1201.595825  1181.328400          NaN
# 2022-04-20  1236.927490  1187.039941          NaN
# 2022-04-21  1265.889160  1192.749207          NaN
# 2022-04-22  1255.287231  1197.745245          NaN
# 2022-04-25  1226.257446  1200.392285          NaN
# 2022-04-26  1262.954102  1204.482843          NaN
# 2022-04-27  1264.182617  1208.041028          NaN
# 2022-04-28  1283.065796  1212.529724          NaN
# 2022-04-29  1269.597412  1215.198370          NaN
# 2022-05-02  1265.138306  1218.513141          NaN
# 2022-05-04  1225.643188  1219.373120          NaN
# 2022-05-05  1201.641235  1218.854407          NaN
# 2022-05-06  1192.427246  1218.731555          NaN
# 2022-05-09  1145.856812  1216.439435          NaN
# 2022-05-10  1125.995483  1214.205316          NaN
# 2022-05-11  1114.461060  1210.420758          NaN
# 2022-05-12  1091.755859  1205.624927          NaN
# 2022-05-13  1104.132202  1202.566107          NaN
# 2022-05-16  1104.405273  1199.734802  1163.602274
# 2022-05-17  1150.793457  1199.400360  1164.790758
# 2022-05-18  1154.979736  1197.069556  1166.247252
# 2022-05-19  1128.361450  1191.641254  1167.651417
# 2022-05-20  1194.156372  1188.054614  1171.154100
# 2022-05-23  1186.170898  1184.598798  1174.533931
# 2022-05-24  1190.243286  1182.798090  1176.915920
# 2022-05-25  1188.491577  1179.074963  1178.915703
# 2022-05-26  1177.161743  1174.723920  1180.626096
# 2022-05-27  1171.701416  1169.155701  1182.048010
# 2022-05-30  1212.516113  1166.301636  1184.790371

# %% [markdown]
# ### RSI — Relative Strength Index
# Momentum indicator ranging 0-100.
# - **Above 70** → Overbought → price may fall
# - **Below 30** → Oversold → price may rise
#
# Built from scratch using `.clip()` to separate gains and losses,
# then 14-day rolling average of each.

# %%
daily_change=df['Close'].diff()
gain=daily_change.clip(lower=0)
loss=daily_change.clip(upper=0).abs()
avg_gain=gain.rolling(14).mean()
avg_loss=loss.rolling(14).mean()
RS=avg_gain/avg_loss
df['RSI']=100-100/(1+RS)

# %%
df.head(60)
# Out:
# Price             Close         High          Low         Open    Volume  \
# Date
# 2022-03-02  1091.369263  1092.484104  1059.814182  1062.202973  21471786
# 2022-03-03  1082.155029  1098.785697  1078.401181  1092.028770  10186748
# 2022-03-04  1058.153198  1075.784852  1055.787154  1070.643199  10805667
# 2022-03-07  1019.022217  1052.033337  1011.036713  1036.835847  17983310
# 2022-03-08  1017.179382  1021.957085   991.926235  1006.259101  21289374
# 2022-03-09  1071.143799  1077.013475  1016.565078  1017.406956  20414228
# 2022-03-10  1088.502441  1094.303876  1073.828372  1092.028820  17980493
# 2022-03-11  1091.642090  1097.034080  1081.131313  1081.131313  12257423
# 2022-03-14  1100.605713  1103.131106  1080.198450  1086.068126   8340678
# 2022-03-15  1075.398071  1104.746328  1065.114766  1104.746328  15925769
# 2022-03-16  1093.553101  1095.623434  1081.609026  1083.838589  11149828
# 2022-03-17  1129.203491  1136.347117  1098.899616  1106.930614  21422098
# 2022-03-21  1122.696655  1130.249846  1109.774342  1112.049398  11999466
# 2022-03-22  1151.703857  1153.432867  1116.417677  1119.375142  22557065
# 2022-03-23  1155.366455  1167.037566  1147.995360  1147.995360  15462187
# 2022-03-24  1173.316650  1175.819296  1142.080154  1142.080154  13168266
# 2022-03-25  1181.142944  1190.311409  1172.565900  1175.068546  14222488
# 2022-03-28  1193.018921  1196.567927  1176.888684  1187.581436   9891424
# 2022-03-29  1193.291870  1200.321762  1186.398460  1200.321762   8684065
# 2022-03-30  1216.224487  1223.072403  1190.812051  1201.186345  15811550
# 2022-03-31  1198.842896  1214.745662  1196.044660  1212.584340  13223718
# 2022-04-01  1208.443604  1212.675258  1193.041512  1199.411620   7922880
# 2022-04-04  1212.015503  1217.157156  1201.982533  1208.261654   7929162
# 2022-04-05  1194.884277  1214.836602  1192.449993  1206.282305  13149870
# 2022-04-06  1191.699219  1198.729109  1177.161631  1177.161631  12257215
# 2022-04-07  1170.677856  1185.761494  1168.015981  1180.801815  15496499
# 2022-04-08  1190.152222  1194.406624  1164.830774  1164.830774  15152495
# 2022-04-11  1187.672485  1200.572053  1175.296098  1183.031265   9254209
# 2022-04-12  1165.308594  1184.214319  1162.737707  1177.116066  13217742
# 2022-04-13  1161.031372  1179.664132  1158.233016  1171.428413  10354235
# 2022-04-18  1157.482300  1164.739781  1147.449330  1152.545489   9974224
# 2022-04-19  1201.595825  1213.972213  1160.758547  1163.920855  26141820
# 2022-04-20  1236.927490  1244.002996  1205.372413  1209.012527  25072240
# 2022-04-21  1265.889160  1269.028721  1243.092981  1251.692774  21708633
# 2022-04-22  1255.287231  1274.943726  1248.644039  1255.332725  15054154
# 2022-04-25  1226.257446  1255.105154  1211.992821  1247.825046  17063215
# 2022-04-26  1262.954102  1271.758615  1232.036062  1233.082542  12227666
# 2022-04-27  1264.182617  1286.773948  1253.580734  1253.944805  19338945
# 2022-04-28  1283.065796  1297.239434  1267.709076  1278.561177  25614076
# 2022-04-29  1269.597412  1299.582709  1263.704989  1299.582709  18214862
# 2022-05-02  1265.138306  1276.536334  1254.945986  1256.743356   9467006
# 2022-05-04  1225.643188  1269.483665  1217.748793  1267.208609  19247660
# 2022-05-05  1201.641235  1242.182800  1197.591676  1239.225215  17210669
# 2022-05-06  1192.427246  1209.876925  1180.096353  1188.582410  19649948
# 2022-05-09  1145.856812  1181.711783  1140.715158  1171.633199  18083752
# 2022-05-10  1125.995483  1149.633417  1118.419545  1135.255057  19511677
# 2022-05-11  1114.461060  1130.682284  1102.016431  1125.085571  16643899
# 2022-05-12  1091.755859  1107.885974  1078.378487  1104.541691  20490321
# 2022-05-13  1104.132202  1127.519799  1099.013296  1103.859239  19308778
# 2022-05-16  1104.405273  1128.884844  1099.604824  1107.704063  13437911
# 2022-05-17  1150.793457  1155.684893  1106.589038  1107.999589  16551828
# 2022-05-18  1154.979736  1169.380842  1141.283906  1155.571277  17276788
# 2022-05-19  1128.361450  1143.217615  1122.082329  1130.249808  14699118
# 2022-05-20  1194.156372  1203.233850  1138.440180  1143.217762  21793091
# 2022-05-23  1186.170898  1207.397173  1179.846163  1197.364083  15252755
# 2022-05-24  1190.243286  1200.321750  1181.984819  1186.216474  13527818
# 2022-05-25  1188.491577  1208.830603  1183.713875  1198.956860  12714544
# 2022-05-26  1177.161743  1198.911319  1159.370738  1194.133617  17882023
# 2022-05-27  1171.701416  1185.374499  1155.776024  1179.868895  16521973
# 2022-05-30  1212.516113  1216.702154  1180.392243  1189.856419  13853398
#
# Price       Target       SMA_20       SMA_50        RSI
# Date
# 2022-03-02       0          NaN          NaN        NaN
# 2022-03-03       0          NaN          NaN        NaN
# 2022-03-04       0          NaN          NaN        NaN
# 2022-03-07       0          NaN          NaN        NaN
# 2022-03-08       1          NaN          NaN        NaN
# 2022-03-09       1          NaN          NaN        NaN
# 2022-03-10       1          NaN          NaN        NaN
# 2022-03-11       1          NaN          NaN        NaN
# 2022-03-14       0          NaN          NaN        NaN
# 2022-03-15       1          NaN          NaN        NaN
# 2022-03-16       1          NaN          NaN        NaN
# 2022-03-17       0          NaN          NaN        NaN
# 2022-03-21       1          NaN          NaN        NaN
# 2022-03-22       1          NaN          NaN        NaN
# 2022-03-23       1          NaN          NaN  61.601853
# 2022-03-24       1          NaN          NaN  66.019017
# 2022-03-25       1          NaN          NaN  72.914526
# 2022-03-28       1          NaN          NaN  86.082233
# 2022-03-29       1          NaN          NaN  86.760338
# 2022-03-30       0  1115.234482          NaN  84.789923
# 2022-03-31       1  1120.608163          NaN  76.456405
# 2022-04-01       1  1126.922592          NaN  77.163945
# 2022-04-04       0  1134.615707          NaN  76.576518
# 2022-04-05       0  1143.408810          NaN  79.645429
# 2022-04-06       0  1152.134802          NaN  76.304798
# 2022-04-07       1  1157.111505          NaN  62.061655
# 2022-04-08       0  1162.193994          NaN  68.241682
# 2022-04-11       0  1166.995514          NaN  61.356130
# 2022-04-12       0  1170.230658          NaN  52.807437
# 2022-04-13       0  1174.512323          NaN  46.240618
# 2022-04-18       1  1177.708783          NaN  42.565048
# 2022-04-19       1  1181.328400          NaN  52.241095
# 2022-04-20       1  1187.039941          NaN  59.636249
# 2022-04-21       0  1192.749207          NaN  60.683194
# 2022-04-22       0  1197.745245          NaN  62.506315
# 2022-04-25       1  1200.392285          NaN  53.634107
# 2022-04-26       1  1204.482843          NaN  59.154467
# 2022-04-27       1  1208.041028          NaN  63.209021
# 2022-04-28       0  1212.529724          NaN  66.432094
# 2022-04-29       0  1215.198370          NaN  68.287308
# 2022-05-02       0  1218.513141          NaN  64.677578
# 2022-05-04       0  1219.373120          NaN  56.491613
# 2022-05-05       0  1218.854407          NaN  56.176966
# 2022-05-06       0  1218.731555          NaN  55.249540
# 2022-05-09       0  1216.439435          NaN  48.300645
# 2022-05-10       0  1214.205316          NaN  38.105812
# 2022-05-11       0  1210.420758          NaN  29.172834
# 2022-05-12       1  1205.624927          NaN  19.742259
# 2022-05-13       1  1202.566107          NaN  23.895979
# 2022-05-16       1  1199.734802  1163.602274  26.635877
# 2022-05-17       1  1199.400360  1164.790758  29.264778
# 2022-05-18       0  1197.069556  1166.247252  30.029975
# 2022-05-19       1  1191.641254  1167.651417  22.487428
# 2022-05-20       0  1188.054614  1171.154100  38.688775
# 2022-05-23       1  1184.598798  1174.533931  38.283941
# 2022-05-24       0  1182.798090  1176.915920  44.130971
# 2022-05-25       0  1179.074963  1178.915703  47.646232
# 2022-05-26       0  1174.723920  1180.626096  47.288041
# 2022-05-27       1  1169.155701  1182.048010  55.376726
# 2022-05-30       0  1166.301636  1184.790371  66.556365

# %%
print(df['RSI'].describe())
print(df['RSI'].head(20))
# Out:
# count    975.000000
# mean      51.485630
# std       17.083184
# min        7.722604
# 25%       38.741114
# 50%       52.553386
# 75%       64.495286
# max       97.563393
# Name: RSI, dtype: float64
# Date
# 2022-03-02          NaN
# 2022-03-03          NaN
# 2022-03-04          NaN
# 2022-03-07          NaN
# 2022-03-08          NaN
# 2022-03-09          NaN
# 2022-03-10          NaN
# 2022-03-11          NaN
# 2022-03-14          NaN
# 2022-03-15          NaN
# 2022-03-16          NaN
# 2022-03-17          NaN
# 2022-03-21          NaN
# 2022-03-22          NaN
# 2022-03-23    61.601853
# 2022-03-24    66.019017
# 2022-03-25    72.914526
# 2022-03-28    86.082233
# 2022-03-29    86.760338
# 2022-03-30    84.789923
# Name: RSI, dtype: float64

# %% [markdown]
# ### MACD — Moving Average Convergence Divergence
# Trend and momentum indicator combining two EMAs.
# - **MACD Line** = 12-day EMA - 26-day EMA
# - **Signal Line** = 9-day EMA of MACD
# - **Histogram** = MACD - Signal Line (our feature)
#
# EMA gives more weight to recent prices than SMA — reacts faster to changes.
# Positive histogram = bullish momentum. Negative = bearish momentum.

# %%
ema_12 = df['Close'].ewm(span=12).mean()
ema_26 = df['Close'].ewm(span=26).mean()

df['MACD'] = ema_12 - ema_26
df['Signal_Line'] = df['MACD'].ewm(span=9).mean()
df['MACD_Histogram'] = df['MACD']-df['Signal_Line']

# %%
df[['MACD', 'Signal_Line', 'MACD_Histogram']].head(30)
# Out:
# Price            MACD  Signal_Line  MACD_Histogram
# Date
# 2022-03-02   0.000000     0.000000        0.000000
# 2022-03-03  -0.206730    -0.114850       -0.091880
# 2022-03-04  -1.007710    -0.480776       -0.526934
# 2022-03-07  -2.760124    -1.252913       -1.507211
# 2022-03-08  -3.727583    -1.989071       -1.738512
# 2022-03-09  -1.931541    -1.973477        0.041937
# 2022-03-10   0.039925    -1.463939        1.503864
# 2022-03-11   1.510532    -0.749118        2.259649
# 2022-03-14   2.950634     0.105543        2.845091
# 2022-03-15   2.630847     0.671358        1.959489
# 2022-03-16   3.330087     1.253073        2.077015
# 2022-03-17   5.755740     2.220057        3.535684
# 2022-03-21   7.110759     3.255099        3.855660
# 2022-03-22   9.713801     4.606265        5.107536
# 2022-03-23  11.770291     6.091321        5.678971
# 2022-03-24  14.271477     7.774736        6.496741
# 2022-03-25  16.486199     9.557165        6.929033
# 2022-03-28  18.728708    11.425124        7.303584
# 2022-03-29  20.241806    13.214244        7.027562
# 2022-03-30  22.658606    15.125148        7.533459
# 2022-03-31  23.104366    16.735847        6.368518
# 2022-04-01  23.818160    18.162839        5.655321
# 2022-04-04  24.332041    19.404006        4.928035
# 2022-04-05  23.266246    20.180119        3.086127
# 2022-04-06  21.942495    20.533931        1.408564
# 2022-04-07  19.178827    20.262089       -1.083262
# 2022-04-08  18.181815    19.845025       -1.663211
# 2022-04-11  17.015185    19.277960       -2.262776
# 2022-04-12  14.294931    18.279810       -3.984879
# 2022-04-13  11.694765    16.961168       -5.266404

# %%
print(df.columns)
print(df.head(2))
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'Target', 'SMA_20', 'SMA_50',
#        'RSI', 'MACD', 'Signal_Line', 'MACD_Histogram'],
#       dtype='object', name='Price')
# Price             Close         High          Low         Open    Volume  \
# Date
# 2022-03-02  1091.369263  1092.484104  1059.814182  1062.202973  21471786
# 2022-03-03  1082.155029  1098.785697  1078.401181  1092.028770  10186748
#
# Price       Target  SMA_20  SMA_50  RSI     MACD  Signal_Line  MACD_Histogram
# Date
# 2022-03-02       0     NaN     NaN  NaN  0.00000      0.00000         0.00000
# 2022-03-03       0     NaN     NaN  NaN -0.20673     -0.11485        -0.09188

# %% [markdown]
# ### Bollinger Bands
# Volatility indicator based on standard deviation.
# - **bb_Width** = (4 × std_20) / SMA_20
#
# Wide bands = high volatility. Narrow bands = low volatility (Bollinger Squeeze).
# We only keep bb_Width as a feature — Upper and Lower bands are
# highly correlated with SMA and add no independent information.

# %%
std_20=df['Close'].rolling(20).std()
df['bb_Upper']=df['SMA_20']+2*std_20
df['bb_Lower']=df['SMA_20']-2*std_20
df['bb_Width']=(df['bb_Upper']-df['bb_Lower'])/df['SMA_20']

# %% [markdown]
# ### Momentum & Volatility
# - **Momentum** = Close - Close.shift(10) → price change over 10 days
# - **Volatility** = 20-day rolling std of daily returns
#
# Note: Volatility uses `pct_change()` not our forward-looking `return_` variable
# to avoid data leakage — standard deviation of returns is the standard
# definition of volatility in finance.

# %%
df['Momentum']=df['Close']-df['Close'].shift(10)
df['Volatility']=return_.rolling(20).std

# %%
df.dropna(inplace=True)
print(df.shape)
# Out:
# (940, 17)

# %% [markdown]
# ## 4. Exploratory Data Analysis
# Visualizing price trends, technical indicators, and feature relationships
# to understand the data before modelling.

# %%
plt.figure(figsize=(14, 6))
plt.plot(df['Close'], label='Close Price', alpha=0.7)
plt.plot(df['SMA_20'], label='SMA 20', alpha=0.8)
plt.plot(df['SMA_50'], label='SMA 50', alpha=0.8)
plt.title('Reliance Industries — Price with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (INR)')
plt.legend()
plt.show()

# %% [markdown]
# **Observation:** SMA 20 crosses above SMA 50 during uptrends (Golden Cross)
# and below during downtrends (Death Cross). These crossovers signal trend changes
# and are among the most watched signals in technical analysis.

# %%
plt.figure(figsize=(14, 5))
plt.plot(df['RSI'], label='RSI', color='purple')
plt.axhline(70, color='red', linestyle='--', label='Overbought (70)')
plt.axhline(30, color='green', linestyle='--', label='Oversold (30)')
plt.title('Reliance Industries — RSI Over Time')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.legend()
plt.show()

# %% [markdown]
# **Observation:** RSI crossed above 70 approximately 21 times (overbought)
# and below 30 approximately 15 times (oversold) during the period.
# Price typically corrected after overbought signals — confirming RSI
# captures meaningful reversal patterns.

# %%
plt.figure(figsize=(14, 5))
plt.bar(df.index, df['MACD_Histogram'], 
        color=df['MACD_Histogram'].apply(lambda x: 'green' if x > 0 else 'red'),
        label='MACD Histogram')
plt.title('Reliance Industries — MACD Histogram')
plt.xlabel('Date')
plt.ylabel('Histogram Value')
plt.legend()
plt.show()

# %% [markdown]
# **Observation:** Extended periods of same-colored bars represent momentum phases —
# sustained bullish or bearish trends. Bars shrinking toward zero indicate
# weakening momentum and potential reversals (momentum divergence).

# %%
daily_return = df['Close'].pct_change().dropna()

plt.figure(figsize=(10, 5))
sns.histplot(daily_return, bins=50, kde=True, color='steelblue')
plt.title('Reliance Industries — Distribution of Daily Returns')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.axvline(daily_return.mean(), color='red', linestyle='--', label='Mean')
plt.axvline(daily_return.std(), color='green', linestyle='--', label='Std Dev')
plt.legend()
plt.show()

# %% [markdown]
# **Observation:** Returns follow an approximately normal distribution centered
# near zero with fat tails (leptokurtosis) — extreme moves occur more frequently
# than pure normality predicts. This is a universal property of equity returns
# consistent with established financial literature.

# %%
print(df.dtypes)
# Out:
# Price
# Close             float64
# High              float64
# Low               float64
# Open              float64
# Volume              int64
# Target              int64
# SMA_20            float64
# SMA_50            float64
# RSI               float64
# MACD              float64
# Signal_Line       float64
# MACD_Histogram    float64
# bb_Upper          float64
# bb_Lower          float64
# bb_Width          float64
# Momentum          float64
# Volatility         object
# dtype: object

# %%
daily_return = df['Close'].pct_change()
df['Volatility'] = daily_return.rolling(20).std()
df['Volatility'] = df['Volatility'].astype(float)

# %%
print(df['Volatility'].dtype)
print(df['Volatility'].head())
# Out:
# float64
# Date
# 2022-05-16   NaN
# 2022-05-17   NaN
# 2022-05-18   NaN
# 2022-05-19   NaN
# 2022-05-20   NaN
# Name: Volatility, dtype: float64

# %%
df.dropna(inplace=True)
print(df.shape)
# Out:
# (920, 17)

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt='.2f', 
            cmap='coolwarm', center=0)
plt.title('Feature Correlation Heatmap')
plt.show()

# %% [markdown]
# **Observation:** High multicollinearity exists between SMA-based features
# and price columns — expected since moving averages are derived from price.
# Target shows low correlation with all features individually, confirming
# that stock direction requires combinations of signals — justifying the use
# of ensemble ML methods over simple rules.

# %%
df.drop(['bb_Upper', 'bb_Lower'], axis=1, inplace=True)
print(df.columns.tolist())
print(df.shape)
# Out:
# ['Close', 'High', 'Low', 'Open', 'Volume', 'Target', 'SMA_20', 'SMA_50', 'RSI', 'MACD', 'Signal_Line', 'MACD_Histogram', 'bb_Width', 'Momentum', 'Volatility']
# (920, 15)

# %%
plt.figure(figsize=(14, 6))
plt.plot(df['Close'], label='Close Price', alpha=0.7)
plt.plot(df['SMA_20'], label='SMA 20', alpha=0.7)

# Recalculate for plotting since we dropped bb_Upper and bb_Lower
std_20 = df['Close'].rolling(20).std()
bb_upper = df['SMA_20'] + 2 * std_20
bb_lower = df['SMA_20'] - 2 * std_20

plt.plot(bb_upper, label='Upper Band', linestyle='--', color='red', alpha=0.6)
plt.plot(bb_lower, label='Lower Band', linestyle='--', color='green', alpha=0.6)
plt.fill_between(df.index, bb_upper, bb_lower, alpha=0.1, color='grey')
plt.title('Reliance Industries — Bollinger Bands')
plt.xlabel('Date')
plt.ylabel('Price (INR)')
plt.legend()
plt.show()

# %% [markdown]
# ## 5. Modelling
# Comparing three classification models using a chronological train/test split.
#
# **Why chronological split?**
# Random splits cause data leakage in time series — future data ends up in
# training and past data in testing. We always train on the past and test
# on the future, exactly as real trading would work.
#
# **Baseline first:** Logistic Regression serves as our baseline.
# Any model that cannot beat it does not justify its added complexity.

# %%
# Define features and target
features = ['Close', 'High', 'Low', 'Open', 'Volume', 
            'SMA_20', 'SMA_50', 'RSI', 'MACD', 
            'Signal_Line', 'MACD_Histogram', 'bb_Width', 
            'Momentum', 'Volatility']

X = df[features]
y = df['Target']

# Chronological split — no shuffling
split = int(len(df) * 0.8)

X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

print(f"Training samples: {len(X_train)}")
print(f"Testing samples: {len(X_test)}")
# Out:
# Training samples: 736
# Testing samples: 184

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train
lr_model = LogisticRegression()
lr_model.fit(X_train_scaled, y_train)

# Predict
lr_pred = lr_model.predict(X_test_scaled)

# Evaluate
print(f"Logistic Regression Accuracy: {accuracy_score(y_test, lr_pred):.4f}")
print(classification_report(y_test, lr_pred))
# Out:
# Logistic Regression Accuracy: 0.4783
#               precision    recall  f1-score   support
#
#            0       0.50      0.74      0.59        95
#            1       0.42      0.20      0.27        89
#
#     accuracy                           0.48       184
#    macro avg       0.46      0.47      0.43       184
# weighted avg       0.46      0.48      0.44       184

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

rf_pred = rf_model.predict(X_test)

print(f"Random Forest Accuracy: {accuracy_score(y_test, rf_pred):.4f}")
print(classification_report(y_test, rf_pred))
# Out:
# Random Forest Accuracy: 0.5326
#               precision    recall  f1-score   support
#
#            0       0.54      0.62      0.58        95
#            1       0.52      0.44      0.48        89
#
#     accuracy                           0.53       184
#    macro avg       0.53      0.53      0.53       184
# weighted avg       0.53      0.53      0.53       184

# %%
ConfusionMatrixDisplay.from_predictions(y_test, rf_pred)
plt.title('Random Forest — Confusion Matrix')
plt.show()

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(n_estimators=100, random_state=42, eval_metric='logloss')
xgb_model.fit(X_train, y_train)

xgb_pred = xgb_model.predict(X_test)

print(f"XGBoost Accuracy: {accuracy_score(y_test, xgb_pred):.4f}")
print(classification_report(y_test, xgb_pred))
# Out:
# XGBoost Accuracy: 0.5054
#               precision    recall  f1-score   support
#
#            0       0.52      0.60      0.56        95
#            1       0.49      0.40      0.44        89
#
#     accuracy                           0.51       184
#    macro avg       0.50      0.50      0.50       184
# weighted avg       0.50      0.51      0.50       184

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10]
}

tscv = TimeSeriesSplit(n_splits=5)

grid_search = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid,
    cv=tscv,
    scoring='accuracy',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)

print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best CV Accuracy: {grid_search.best_score_:.4f}")
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}
# Best CV Accuracy: 0.5115

# %%
best_rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=None,
    min_samples_split=5,
    random_state=42
)

best_rf.fit(X_train, y_train)
best_rf_pred = best_rf.predict(X_test)

print(f"Tuned Random Forest Accuracy: {accuracy_score(y_test, best_rf_pred):.4f}")
print(classification_report(y_test, best_rf_pred))
# Out:
# Tuned Random Forest Accuracy: 0.4891
#               precision    recall  f1-score   support
#
#            0       0.50      0.66      0.57        95
#            1       0.46      0.30      0.36        89
#
#     accuracy                           0.49       184
#    macro avg       0.48      0.48      0.47       184
# weighted avg       0.48      0.49      0.47       184

# %%
feature_importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': rf_model.feature_importances_
}).sort_values('Importance', ascending=False)

print(feature_importance)

# Plot
plt.figure(figsize=(10, 6))
plt.barh(feature_importance['Feature'], feature_importance['Importance'])
plt.xlabel('Importance Score')
plt.title('Random Forest — Feature Importance')
plt.gca().invert_yaxis()
plt.show()
# Out:
#            Feature  Importance
# 4           Volume    0.091210
# 11        bb_Width    0.077351
# 13      Volatility    0.075831
# 7              RSI    0.073233
# 10  MACD_Histogram    0.072920
# 2              Low    0.070936
# 12        Momentum    0.070499
# 3             Open    0.069423
# 8             MACD    0.069327
# 0            Close    0.067970
# 9      Signal_Line    0.067950
# 5           SMA_20    0.067643
# 6           SMA_50    0.063540
# 1             High    0.062167

# %% [markdown]
# ## 6. Strategy Evaluation
#
# **Beyond accuracy — Strategy Returns**
# Accuracy alone is a misleading metric for financial models. A model can be
# right 51% of the time and still be extremely profitable if it's right
# at the right moments.
#
# We compare our ML strategy against a simple buy and hold benchmark:
# - **Buy & Hold** — buy and hold Reliance for the entire test period
# - **ML Strategy** — buy only when model predicts UP, stay out when DOWN

# %%
# Get actual returns for test period
test_returns = df['Close'].pct_change().iloc[split+1:].values
rf_pred_aligned = rf_pred[:len(test_returns)]

# Strategy — buy when model predicts up, stay out when predicts down
strategy_returns = test_returns * rf_pred_aligned

# Cumulative returns
cumulative_market = (1 + test_returns).cumprod()
cumulative_strategy = (1 + strategy_returns).cumprod()

plt.figure(figsize=(14, 6))
plt.plot(cumulative_market, label='Buy & Hold', color='blue')
plt.plot(cumulative_strategy, label='ML Strategy', color='green')
plt.title('Strategy Returns — ML Model vs Buy & Hold')
plt.xlabel('Trading Days')
plt.ylabel('Cumulative Return')
plt.legend()
plt.show()

print(f"Buy & Hold Return: {(cumulative_market[-1]-1)*100:.2f}%")
print(f"ML Strategy Return: {(cumulative_strategy[-1]-1)*100:.2f}%")
# Out:
# Buy & Hold Return: -3.05%
# ML Strategy Return: 1.29%

# %% [markdown]
# **Finding:** The ML strategy outperformed buy and hold during the test period
# by preserving capital on predicted down days. This demonstrates the model's
# value as a **defensive strategy** — reducing drawdown rather than maximising gains.
#
# **Note on market regime:** Model performance varies with market conditions.
# During strong bull markets, buy and hold is hard to beat. The model adds
# most value in choppy or declining markets.

# %%
print(f"Random Forest Accuracy: {accuracy_score(y_test, rf_pred):.4f}")
print(classification_report(y_test, rf_pred))
print(f"\nBuy & Hold Return: {(cumulative_market[-1]-1)*100:.2f}%")
print(f"ML Strategy Return: {(cumulative_strategy[-1]-1)*100:.2f}%")
# Out:
# Random Forest Accuracy: 0.5326
#               precision    recall  f1-score   support
#
#            0       0.54      0.62      0.58        95
#            1       0.52      0.44      0.48        89
#
#     accuracy                           0.53       184
#    macro avg       0.53      0.53      0.53       184
# weighted avg       0.53      0.53      0.53       184
#
#
# Buy & Hold Return: -3.05%
# ML Strategy Return: 1.29%

# %%
fig, ax = plt.subplots(figsize=(6, 5))
ConfusionMatrixDisplay.from_predictions(
    y_test,
    rf_pred,
    display_labels=['DOWN (0)', 'UP (1)'],
    cmap='Blues',
    ax=ax
)
plt.title('Random Forest — Confusion Matrix')
plt.show()

# %%
import joblib
joblib.dump(rf_model, 'best_model.joblib')
print("Model saved successfully")
# Out:
# Model saved successfully

# %% [markdown]
# ## 7. Live Prediction
# Generating a trading signal for the next trading day based on latest market data.
#
# The model uses yesterday's closing data to predict tomorrow's direction.
# **Best run after 3:30 PM IST** when today's data is final.
#
# This is implemented as a full web application in `app.py` using Streamlit,
# allowing predictions for any NSE listed stock.

# %% [markdown]
# ## Conclusions & Limitations
#
# ### Key Findings
# - Random Forest outperformed Logistic Regression and XGBoost
# - Volume is the most important predictive feature (9.09% importance)
# - Model shows defensive bias — better at identifying DOWN days (61%) than UP days (44%)
# - Strategy outperformed buy and hold during the test period
#
# ### Limitations
# - Based on technical indicators only — no fundamental or sentiment data
# - Performance varies significantly with market regime
# - Transaction costs not accounted for
# - 53% accuracy confirms Efficient Market Hypothesis — public information is largely priced in
#
# ### Future Work
# - Add news sentiment analysis using NLP
# - Include fundamental data (P/E ratio, EPS growth)
# - Implement walk-forward validation
# - Expand to multiple stocks simultaneously
# - Add Sharpe ratio and maximum drawdown metrics

# %%
import sys
sys.path.append('.')

from src.data_loader import download_stock_data
from src.features import calculate_features, FEATURES

df_raw = download_stock_data("RELIANCE.NS", "2022-01-01", "2025-01-01")
df = calculate_features(df_raw)
print(df.shape)
print(df.columns.tolist())
# Out:
# [*********************100%***********************]  1 of 1 completed
# (690, 15)
# ['Close', 'High', 'Low', 'Open', 'Volume', 'SMA_20', 'SMA_50', 'RSI', 'MACD', 'Signal_Line', 'MACD_Histogram', 'bb_Width', 'Momentum', 'Volatility', 'Target']

# %%
from src.model import train_test_split_timeseries, train_random_forest, evaluate_model

X_train, X_test, y_train, y_test, split = train_test_split_timeseries(df, FEATURES)
model = train_random_forest(X_train, y_train)
predictions, accuracy, report = evaluate_model(model, X_test, y_test)

print(f"Accuracy: {accuracy:.4f}")
print(report)
# Out:
# Accuracy: 0.5290
#               precision    recall  f1-score   support
#
#            0       0.53      0.52      0.53        69
#            1       0.53      0.54      0.53        69
#
#     accuracy                           0.53       138
#    macro avg       0.53      0.53      0.53       138
# weighted avg       0.53      0.53      0.53       138

# %%
from src.utils import plot_price_with_sma
import matplotlib.pyplot as plt

fig = plot_price_with_sma(df, "RELIANCE.NS")
plt.show()

# %%
from src.sentiment import get_news_sentiment, interpret_sentiment

# Replace with your actual API key
API_KEY = "71d668f9bbe543da94b23c3aaeb74bd1"

score, headlines = get_news_sentiment("RELIANCE.NS", API_KEY)

print(f"Overall Sentiment Score: {score:.4f}")
print(f"Sentiment: {interpret_sentiment(score)}")
print(f"\nTop 5 Headlines:")
for h in headlines[:5]:
    print(f"  {h['sentiment']:.3f} — {h['headline']}")
# Out:
# Overall Sentiment Score: 0.0214
# Sentiment: Neutral 😐
#
# Top 5 Headlines:
#   0.273 — Manufactured Savings: How Ember Turns Assumptions into Energy Policy
#   0.586 — Alani Nu Energy Drink: 10 Must-Know Facts on Viral Zero-Sugar Boost as Sales Soar
#   0.000 — LPG carrier Jag Vikram first India-flagged vessel to cross Hormuz after US–Iran ceasefire
#   0.000 — The Way You Eat Carbs Could Shape Your Brain Health Decades Later
#   0.318 — Indonesia considers EV incentives with industry, regulators

# %%
score, headlines = get_news_sentiment("RELIANCE.NS", API_KEY)

print(f"Overall Sentiment Score: {score:.4f}")
print(f"Sentiment: {interpret_sentiment(score)}")
print(f"\nTop 5 Headlines:")
for h in headlines[:5]:
    print(f"  {h['sentiment']:.3f} — {h['headline']}")
# Out:
# Overall Sentiment Score: 0.0214
# Sentiment: Neutral 😐
#
# Top 5 Headlines:
#   0.273 — Manufactured Savings: How Ember Turns Assumptions into Energy Policy
#   0.586 — Alani Nu Energy Drink: 10 Must-Know Facts on Viral Zero-Sugar Boost as Sales Soar
#   0.000 — LPG carrier Jag Vikram first India-flagged vessel to cross Hormuz after US–Iran ceasefire
#   0.000 — The Way You Eat Carbs Could Shape Your Brain Health Decades Later
#   0.318 — Indonesia considers EV incentives with industry, regulators

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.moneycontrol.com/stocks/company_info/stock_news.php?sc_id=RI"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
print(f"Status code: {response.status_code}")
print(f"Page length: {len(response.text)}")
print(response.text[:2000])
# Out:
# Status code: 200
# Page length: 516948
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html xmlns="https://www.w3.org/1999/xhtml">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#
# <title>Reliance News: Latest News Updates on Reliance, Reliance Results News, News on Reliance for last 6 months,  Reliance Share/Stock News</title>
# <meta name="description" content="Get latest Reliance News/Updates and Results/Analysis. Also get Reliance Share/Stock detailed Information on Reliance along with top stories and articles on Reliance during last 6 months." />
#
# <meta name="keywords" content="Reliance Industries Results, Reliance Industries Q1/Q2/Q3/Q4 Results News, Reliance Industries Second Quarter Results News, Reliance Industries Quarterly Results News, Reliance Industries Results Analysis, Reliance Industries News article, Reliance Industries updates, Reliance Industries news today, Reliance Industries news {2011}, latest Reliance Industries news, Reliance Industries news {2011}, Reliance Industries news {2010}, Reliance Industries news {2009}, Reliance Industries news {2008}
# " />
#
#
#
# <!-- Canonical Notification Start -->
# <link rel="canonical" href="http://www.moneycontrol.com/stocks/company_info/stock_news.php?sc_id=RI" />
# <!-- Canonical Notification End -->
#
# <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon">
# <link rel="stylesheet" type="text/css" href="https://stat2.moneycontrol.com/mccss/news_center09/https_main.css" />
#
# <style type="text/css">
# a{text-decoration:none}a:hover{text-decoration:underline}
# #dhtmltooltip12{position: absolute;FONT-FAMILY:arial;FONT-SIZE:12px;visibility: hidden;background-color:transparent;z-index: 10;}
# .searchcont{float:left; background:#262626; width:438px; padding:7px 4px 3px 4px; height:27px; }
# .searchcont .sinput{float:left; border:1px solid #666; padding:4px 5px 4px 5px; font:11px arial; color:#333333; width:358px;}
# </style>
# <style>
# *{padding:0; margin:0;}
# #s

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# Try to find news headlines
headlines = soup.find_all('h2')
print(f"Found {len(headlines)} h2 tags")
for h in headlines[:10]:
    print(h.text.strip())
# Out:
# Found 0 h2 tags

# %%
# Try different tags
for tag in ['h1', 'h2', 'h3', 'h4', 'a', 'p']:
    elements = soup.find_all(tag)
    print(f"{tag}: {len(elements)} found")
# Out:
# h1: 1 found
# h2: 0 found
# h3: 0 found
# h4: 0 found
# a: 675 found
# p: 110 found

# %%
# Print all anchor tag texts to find headlines
for a in soup.find_all('a')[:50]:
    text = a.text.strip()
    if len(text) > 30:  # only show meaningful text, not short links
        print(text)
# Out:
# HDFC Bank INE040A01034, HDFCBANK, 500180
# Reliance INE002A01018, RELIANCE, 500325
# Ola Electric INE0LXG01040, OLAELEC, 544225
# Vedanta INE205A01025, VEDL, 500295
# Adani Power INE814H01029, ADANIPOWER, 533096

# %%
import requests
from bs4 import BeautifulSoup

def scrape_yahoo_finance_news(ticker):
    """Scrape news headlines from Yahoo Finance for a given ticker."""
    
    url = f"https://finance.yahoo.com/quote/{ticker}/news"
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
    }
    
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all anchor tags with meaningful text
    headlines = []
    for a in soup.find_all('a'):
        text = a.text.strip()
        if len(text) > 30:
            headlines.append(text)
    
    return headlines[:20]

headlines = scrape_yahoo_finance_news("RELIANCE.NS")
for h in headlines:
    print(h)

# %%
import yfinance as yf

ticker = yf.Ticker("RELIANCE.NS")
news = ticker.news

print(f"Found {len(news)} news articles")
for article in news[:5]:
    print(article)
# Out:
# Found 10 news articles
# {'id': 'e3d64567-6fb7-3585-a3a8-78becf60edae', 'content': {'id': 'e3d64567-6fb7-3585-a3a8-78becf60edae', 'contentType': 'STORY', 'title': 'India permits Iranian oil tankers to berth for Reliance, sources say', 'description': '', 'summary': "By Nidhi Verma and Jonathan Saul NEW DELHI/LONDON, April 10 (Reuters) - India's shipping ministry has granted special permission to four vessels carrying Iranian oil - as requested by Reliance", 'pubDate': '2026-04-10T16:08:02Z', 'displayTime': '2026-04-10T16:08:02Z', 'isHosted': True, 'bypassModal': False, 'previewUrl': None, 'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/reuters.com/288e0949c131b8a2465a5107d740bd26', 'originalWidth': 800, 'originalHeight': 562, 'caption': 'A bird flies past a Reliance Industries logo installed on its mart in Ahmedabad, India January 16, 2017. REUTERS/Amit Dave', 'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/qrgw1ZIK8.aDmNHlGYIyRA--~B/aD01NjI7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/288e0949c131b8a2465a5107d740bd26', 'width': 800, 'height': 562, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/YhvlOO32rVeyDjthja_f7g--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/288e0949c131b8a2465a5107d740bd26', 'width': 170, 'height': 128, 'tag': '170x128'}]}, 'provider': {'displayName': 'Reuters', 'url': 'https://www.reuters.com/', 'sourceId': 'reuters.com'}, 'canonicalUrl': {'url': 'https://sg.finance.yahoo.com/news/india-permits-iranian-oil-tankers-140136058.html', 'site': 'finance', 'region': 'SG', 'lang': 'en-SG'}, 'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/india-permits-iranian-oil-tankers-140136058.html', 'site': 'finance', 'region': 'US', 'lang': 'en-US'}, 'metadata': {'editorsPick': False}, 'finance': {'premiumFinance': {'isPremiumNews': False, 'isPremiumFreeNews': False}}, 'storyline': None}}
# {'id': 'd70e5b3d-a1d3-38a3-82a8-8ee803b9df54', 'content': {'id': 'd70e5b3d-a1d3-38a3-82a8-8ee803b9df54', 'contentType': 'STORY', 'title': "India's Reliance buys Venezuelan oil directly from PDVSA, document and data show", 'description': '', 'summary': "By Marianna Parraga April 6 (Reuters) - A unit of India's refiner Reliance Industries has begun\xa0loading a 2-million-barrel cargo of Venezuelan heavy crude directly bought from state-run energy company", 'pubDate': '2026-04-06T14:53:53Z', 'displayTime': '2026-04-06T14:53:53Z', 'isHosted': True, 'bypassModal': False, 'previewUrl': None, 'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/reuters.com/ab56387db8d75b268c01c06ba39b7f92', 'originalWidth': 800, 'originalHeight': 533, 'caption': 'FILE PHOTO: Fuel tank trucks of Venezuelan state oil company PDVSA parked at Puerto La Cruz oil refinery in Puerto La Cruz, Venezuela, January 21, 2026. REUTERS/Stringer/File Photo', 'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/znt1_2R4FJeHtGam0VtivQ--~B/aD01MzM7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/ab56387db8d75b268c01c06ba39b7f92', 'width': 800, 'height': 533, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/x0kZHGaFL26HlnDLLP3aVw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/ab56387db8d75b268c01c06ba39b7f92', 'width': 170, 'height': 128, 'tag': '170x128'}]}, 'provider': {'displayName': 'Reuters', 'url': 'https://www.reuters.com/', 'sourceId': 'reuters.com'}, 'canonicalUrl': {'url': 'https://sg.finance.yahoo.com/news/indias-reliance-buys-venezuelan-oil-140723293.html', 'site': 'finance', 'region': 'SG', 'lang': 'en-SG'}, 'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/indias-reliance-buys-venezuelan-oil-140723293.html', 'site': 'finance', 'region': 'US', 'lang': 'en-US'}, 'metadata': {'editorsPick': False}, 'finance': {'premiumFinance': {'isPremiumNews': False, 'isPremiumFreeNews': False}}, 'storyline': None}}
# {'id': 'a93eb5f0-a11d-340c-90c4-328fcf2820f7', 'content': {'id': 'a93eb5f0-a11d-340c-90c4-328fcf2820f7', 'contentType': 'STORY', 'title': 'How The Investment Story For Reliance Industries (NSEI:RELIANCE) Is Quietly Shifting On New Assumptions', 'description': '', 'summary': 'Reliance Industries has seen its assessed fair value adjusted slightly higher, from ₹1,717.11 to ₹1,719.94, a move of about ₹2.83. This kind of fine tuning lines up with how analysts across sectors are currently tweaking price targets rather than overhauling their views after strong share price moves. Read on to see what is driving this update and how you can track the evolving narrative around Reliance from here. Stay updated as the Fair Value for Reliance Industries shifts by adding it to...', 'pubDate': '2026-04-03T14:07:15Z', 'displayTime': '2026-04-03T14:07:15Z', 'isHosted': True, 'bypassModal': False, 'previewUrl': None, 'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/simply_wall_st__316/0485d0c1021bfa3ad2518a171bbc021d', 'originalWidth': 1194, 'originalHeight': 432, 'caption': '', 'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/afwZ9FGjLmcR0P9A0eObAg--~B/aD00MzI7dz0xMTk0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/0485d0c1021bfa3ad2518a171bbc021d', 'width': 1194, 'height': 432, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/hgDWMeCKA94KLZ_d6_T8pg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/simply_wall_st__316/0485d0c1021bfa3ad2518a171bbc021d', 'width': 170, 'height': 128, 'tag': '170x128'}]}, 'provider': {'displayName': 'Simply Wall St.', 'url': 'https://simplywall.st/', 'sourceId': 'simply_wall_st__316'}, 'canonicalUrl': {'url': 'https://finance.yahoo.com/markets/stocks/articles/investment-story-reliance-industries-nsei-140715800.html', 'site': 'finance', 'region': 'US', 'lang': 'en-US'}, 'clickThroughUrl': {'url': 'https://finance.yahoo.com/markets/stocks/articles/investment-story-reliance-industries-nsei-140715800.html', 'site': 'finance', 'region': 'US', 'lang': 'en-US'}, 'metadata': {'editorsPick': False}, 'finance': {'premiumFinance': {'isPremiumNews': False, 'isPremiumFreeNews': False}}, 'storyline': None}}
# {'id': 'a5d8e509-08e1-3553-b31b-be28e1f57990', 'content': {'id': 'a5d8e509-08e1-3553-b31b-be28e1f57990', 'contentType': 'STORY', 'title': 'India diesel exports to SE Asia hit 7-year high in March due to Iran war, data shows', 'description': '', 'summary': "By Trixie Yap SINGAPORE, March 31 (Reuters) - India's diesel exports to Southeast Asia surged to the highest in more than seven years in March, shipping data showed, as traders pivoted supply to cover", 'pubDate': '2026-04-01T01:51:53Z', 'displayTime': '2026-04-01T01:51:53Z', 'isHosted': True, 'bypassModal': False, 'previewUrl': None, 'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/reuters.com/aa3c593268600bf25d0893471c66b8b9', 'originalWidth': 800, 'originalHeight': 501, 'caption': 'FILE PHOTO: A worker fills diesel in a container at a fuel station in Kolkata, India, February 1, 2018. REUTERS/Rupak De Chowdhuri/File Photo', 'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/JL0Ph0FFAJrmIIYlbdnWzg--~B/aD01MDE7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/aa3c593268600bf25d0893471c66b8b9', 'width': 800, 'height': 501, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/DiSPUlS2a.r8X9_k.bS.eg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/aa3c593268600bf25d0893471c66b8b9', 'width': 170, 'height': 128, 'tag': '170x128'}]}, 'provider': {'displayName': 'Reuters', 'url': 'https://www.reuters.com/', 'sourceId': 'reuters.com'}, 'canonicalUrl': {'url': 'https://sg.finance.yahoo.com/news/india-diesel-exports-se-asia-091604646.html', 'site': 'finance', 'region': 'SG', 'lang': 'en-SG'}, 'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/india-diesel-exports-se-asia-091604646.html', 'site': 'finance', 'region': 'US', 'lang': 'en-US'}, 'metadata': {'editorsPick': False}, 'finance': {'premiumFinance': {'isPremiumNews': False, 'isPremiumFreeNews': False}}, 'storyline': None}}
# {'id': '6ef51c36-f43d-3cb2-b911-95aae5f615a2', 'content': {'id': '6ef51c36-f43d-3cb2-b911-95aae5f615a2', 'contentType': 'STORY', 'title': 'OpenAI Appoints JioStar CEO to Lead Asia Expansion Targeting 1.4 Billion India Market', 'description': '', 'summary': "New Asia-Pacific leadership and Tata partnership highlight OpenAI's push into high-growth regional markets.", 'pubDate': '2026-03-26T12:28:31Z', 'displayTime': '2026-03-26T12:28:31Z', 'isHosted': True, 'bypassModal': False, 'previewUrl': None, 'thumbnail': None, 'provider': {'displayName': 'GuruFocus.com', 'url': 'http://www.gurufocus.com/', 'sourceId': 'us.finance.gurufocus'}, 'canonicalUrl': {'url': 'https://finance.yahoo.com/sectors/technology/articles/openai-appoints-jiostar-ceo-lead-122831848.html', 'site': 'finance', 'region': 'US', 'lang': 'en-US'}, 'clickThroughUrl': {'url': 'https://finance.yahoo.com/sectors/technology/articles/openai-appoints-jiostar-ceo-lead-122831848.html', 'site': 'finance', 'region': 'US', 'lang': 'en-US'}, 'metadata': {'editorsPick': False}, 'finance': {'premiumFinance': {'isPremiumNews': False, 'isPremiumFreeNews': False}}, 'storyline': None}}

# %%
import importlib
import src.sentiment
importlib.reload(src.sentiment)

from src.sentiment import get_news_sentiment, interpret_sentiment

score, headlines = get_news_sentiment("RELIANCE.NS")

print(f"Overall Sentiment Score: {score:.4f}")
print(f"Sentiment: {interpret_sentiment(score)}")
print(f"\nTop 5 Headlines:")
for h in headlines[:5]:
    print(f"  {h['sentiment']:.3f} — {h['headline']}")
# Out:
# Overall Sentiment Score: -0.0979
# Sentiment: Negative 😟
#
# Top 5 Headlines:
#   0.000 — India permits Iranian oil tankers to berth for Reliance, sources say
#   0.000 — India's Reliance buys Venezuelan oil directly from PDVSA, document and data show
#   0.000 — How The Investment Story For Reliance Industries (NSEI:RELIANCE) Is Quietly Shifting On New Assumptions
#   -0.599 — India diesel exports to SE Asia hit 7-year high in March due to Iran war, data shows
#   0.000 — OpenAI Appoints JioStar CEO to Lead Asia Expansion Targeting 1.4 Billion India Market
